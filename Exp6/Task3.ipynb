# %%
# 仅用于校验
import rsa

p = 2**31 - 1
q = 2**61 - 1
e = 65537
n = p * q
message = 19361812491 

phi_n = (p - 1) * (q - 1)
d = pow(e, -1, phi_n)

public_key = rsa.PublicKey(n, e)
private_key = rsa.PrivateKey(n, e, d, p, q)

def encrypt_without_padding(plaintext_int: int, pub_key: rsa.PublicKey) -> int:
    """无填充RSA加密（直接对整数进行模幂运算）"""
    if plaintext_int >= pub_key.n:
        raise ValueError(f"明文必须小于模数 n ({pub_key.n})")
    return pow(plaintext_int, pub_key.e, pub_key.n)

def decrypt_without_padding(ciphertext_int: int, priv_key: rsa.PrivateKey) -> int:
    """无填充RSA解密"""
    return pow(ciphertext_int, priv_key.d, priv_key.n)

# %%
print(f"原始明文（整数）: {message}")
encrypted_int = encrypt_without_padding(message, public_key)
print(f"加密后（整数）: {encrypted_int}")
decrypted_int = decrypt_without_padding(encrypted_int, private_key)
print(f"解密后（整数）: {decrypted_int}")
assert message == decrypted_int, "解密失败！"
print("解密成功，原始明文与解密结果一致。")
# Out:
# 原始明文（整数）: 19361812491
# 加密后（整数）: 4281657302399292598109324838
# 解密后（整数）: 19361812491
# 解密成功，原始明文与解密结果一致。

# %%
# 以下是 RSA 手写函数
def extended_gcd(a, b):
    '''ax + by = gcd'''
    if a == 0:
        return (b, 0, 1)
    gcd, x1, y1 = extended_gcd(b % a, a)
    x = y1 - (b // a) * x1
    y = x1
    return (gcd, x, y)

def Enc(m, N, e):
    return pow(m, e, N) 

def Dec(c, N, d):
    return pow(c, d, N)

p = 2**31 - 1
q = 2**61 - 1
N = p * q
φ_N = (p-1) * (q-1)
e = 65537

gcd, x, y = extended_gcd(e, φ_N)
if gcd == 1:
    print("e的取值满足条件")
else:
    print("e的取值不满足条件，需要重新选择")

d = x % φ_N

m = 19361812491  
c = Enc(m, N, e) 
print(f"加密结果：{c}")

dec_c = Dec(c, N, d)
print(f"解密结果：{dec_c}")

if dec_c == m:
    print("解密成功！")
else:
    print("解密失败！")
# Out:
# e的取值满足条件
# 加密结果：4281657302399292598109324838
# 解密结果：19361812491
# 解密成功！

# %%
if encrypted_int == c:
    print("手写与 rsa 库加密结果一致")
else:
    print("手写与 rsa 库加密结果不一致")
# Out:
# 手写与 rsa 库加密结果一致

# %%
import random
for i in range(100):
    print(f"第{i+1}次测试")
    m = random.randint(1, N-1)
    c_ = Enc(m, N, e)
    print("手写函数的加密结果：", c)
    encrypted_int_ = encrypt_without_padding(m, public_key)
    print("rsa 库的加密结果：", encrypted_int_)
    if encrypted_int_ == c_:
        print("手写与 rsa 库加密结果一致")
    else:
        print("手写与 rsa 库加密结果不一致")
        raise ValueError("加密结果不一致！")
# Out:
# 第1次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2012231241250636487140718741
# 手写与 rsa 库加密结果一致
# 第2次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2872295872100710988596172019
# 手写与 rsa 库加密结果一致
# 第3次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2738644214270564305498864019
# 手写与 rsa 库加密结果一致
# 第4次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1934683979797786603818003069
# 手写与 rsa 库加密结果一致
# 第5次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1259050220668239630409182512
# 手写与 rsa 库加密结果一致
# 第6次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1092352602874467743798459720
# 手写与 rsa 库加密结果一致
# 第7次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4175465146401713905619683955
# 手写与 rsa 库加密结果一致
# 第8次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4288838053037850273800672022
# 手写与 rsa 库加密结果一致
# 第9次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4263531177900165852486674481
# 手写与 rsa 库加密结果一致
# 第10次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2397306473410311567595364328
# 手写与 rsa 库加密结果一致
# 第11次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1881539202146069414412024477
# 手写与 rsa 库加密结果一致
# 第12次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3093443829866829911792929538
# 手写与 rsa 库加密结果一致
# 第13次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2905718403511783419355935091
# 手写与 rsa 库加密结果一致
# 第14次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2979267091530184474903362568
# 手写与 rsa 库加密结果一致
# 第15次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 544073183874166592812783720
# 手写与 rsa 库加密结果一致
# 第16次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4336588733121274509214008300
# 手写与 rsa 库加密结果一致
# 第17次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 382871174861408297452223437
# 手写与 rsa 库加密结果一致
# 第18次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 878215469842939194521820724
# 手写与 rsa 库加密结果一致
# 第19次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2160084289059248726309063693
# 手写与 rsa 库加密结果一致
# 第20次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4772604275693664915206974497
# 手写与 rsa 库加密结果一致
# 第21次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2031763394582715944531175284
# 手写与 rsa 库加密结果一致
# 第22次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3855686101379733687462540834
# 手写与 rsa 库加密结果一致
# 第23次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3963567632239304380299831635
# 手写与 rsa 库加密结果一致
# 第24次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1325028451100065124527456431
# 手写与 rsa 库加密结果一致
# 第25次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4073669294089866164064726738
# 手写与 rsa 库加密结果一致
# 第26次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 834001364287505788683392393
# 手写与 rsa 库加密结果一致
# 第27次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 655626328343790377364746409
# 手写与 rsa 库加密结果一致
# 第28次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3703467190343464530092594585
# 手写与 rsa 库加密结果一致
# 第29次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1302028456375236768341613833
# 手写与 rsa 库加密结果一致
# 第30次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 388778563425116653281846803
# 手写与 rsa 库加密结果一致
# 第31次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 460387233358457439451880681
# 手写与 rsa 库加密结果一致
# 第32次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4918967510624684144791636744
# 手写与 rsa 库加密结果一致
# 第33次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4655409148275625885167216463
# 手写与 rsa 库加密结果一致
# 第34次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1034469883678897261392304342
# 手写与 rsa 库加密结果一致
# 第35次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2448653934471920592200696764
# 手写与 rsa 库加密结果一致
# 第36次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 511443830145154924064638503
# 手写与 rsa 库加密结果一致
# 第37次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3361181783960707494755381484
# 手写与 rsa 库加密结果一致
# 第38次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1672723042536839037637513684
# 手写与 rsa 库加密结果一致
# 第39次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4096725070797912802785474259
# 手写与 rsa 库加密结果一致
# 第40次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1254505247754328502475104384
# 手写与 rsa 库加密结果一致
# 第41次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 842632297498960772591197077
# 手写与 rsa 库加密结果一致
# 第42次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4056802353471145122611553476
# 手写与 rsa 库加密结果一致
# 第43次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2119642076262440272638518771
# 手写与 rsa 库加密结果一致
# 第44次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3455533544384086298423539043
# 手写与 rsa 库加密结果一致
# 第45次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3852958010874918455971472197
# 手写与 rsa 库加密结果一致
# 第46次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4104626158845303816980659130
# 手写与 rsa 库加密结果一致
# 第47次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2450669862676421466194560388
# 手写与 rsa 库加密结果一致
# 第48次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3704039127642676188205862230
# 手写与 rsa 库加密结果一致
# 第49次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3722930685098992955287857293
# 手写与 rsa 库加密结果一致
# 第50次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3123273408951940420167552966
# 手写与 rsa 库加密结果一致
# 第51次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3998279030097222988681416020
# 手写与 rsa 库加密结果一致
# 第52次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3673314297475349302136242767
# 手写与 rsa 库加密结果一致
# 第53次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2931105047724863381236037026
# 手写与 rsa 库加密结果一致
# 第54次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3868656334400605590976237764
# 手写与 rsa 库加密结果一致
# 第55次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1962631998498829065311991152
# 手写与 rsa 库加密结果一致
# 第56次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1363193326082273439649327644
# 手写与 rsa 库加密结果一致
# 第57次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1741820226319106990386571981
# 手写与 rsa 库加密结果一致
# 第58次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1255540579416202621751539509
# 手写与 rsa 库加密结果一致
# 第59次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3867311056922242385203593867
# 手写与 rsa 库加密结果一致
# 第60次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1374447075935251122387806545
# 手写与 rsa 库加密结果一致
# 第61次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2323344808183644161458679314
# 手写与 rsa 库加密结果一致
# 第62次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2605191072200430289102666735
# 手写与 rsa 库加密结果一致
# 第63次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1686967595074972387902708477
# 手写与 rsa 库加密结果一致
# 第64次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4435326625025146829663995417
# 手写与 rsa 库加密结果一致
# 第65次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2027660389197874192612370895
# 手写与 rsa 库加密结果一致
# 第66次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 925982988929452405987873635
# 手写与 rsa 库加密结果一致
# 第67次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1120202555720861813409418849
# 手写与 rsa 库加密结果一致
# 第68次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4190303227825578957882585258
# 手写与 rsa 库加密结果一致
# 第69次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1814587297710318512459459711
# 手写与 rsa 库加密结果一致
# 第70次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1387676963597997454401923943
# 手写与 rsa 库加密结果一致
# 第71次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1924618683988264169411662751
# 手写与 rsa 库加密结果一致
# 第72次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2459130115274993013553117943
# 手写与 rsa 库加密结果一致
# 第73次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3085383815442758498755417063
# 手写与 rsa 库加密结果一致
# 第74次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4565174893219302355253864391
# 手写与 rsa 库加密结果一致
# 第75次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1633769564657181916552391455
# 手写与 rsa 库加密结果一致
# 第76次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4578156773675245582080652221
# 手写与 rsa 库加密结果一致
# 第77次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3064686598702941777113814638
# 手写与 rsa 库加密结果一致
# 第78次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 2689143419826905601016673879
# 手写与 rsa 库加密结果一致
# 第79次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 753973726916733029777772389
# 手写与 rsa 库加密结果一致
# 第80次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4041541034826196232098103978
# 手写与 rsa 库加密结果一致
# 第81次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3449235355009950062671344383
# 手写与 rsa 库加密结果一致
# 第82次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3524673141365636587975963798
# 手写与 rsa 库加密结果一致
# 第83次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1471681597342170571724908497
# 手写与 rsa 库加密结果一致
# 第84次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3974356633105736670096399950
# 手写与 rsa 库加密结果一致
# 第85次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4341411657967037529901768224
# 手写与 rsa 库加密结果一致
# 第86次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1911776236075435347816012903
# 手写与 rsa 库加密结果一致
# 第87次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1791408929084809028818011283
# 手写与 rsa 库加密结果一致
# 第88次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4647715583476291750848487005
# 手写与 rsa 库加密结果一致
# 第89次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 819454732069077872538556987
# 手写与 rsa 库加密结果一致
# 第90次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3954605140050396636127177317
# 手写与 rsa 库加密结果一致
# 第91次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1778801131940514853208312483
# 手写与 rsa 库加密结果一致
# 第92次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4553760732736352782401741043
# 手写与 rsa 库加密结果一致
# 第93次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3401047067339627419404465580
# 手写与 rsa 库加密结果一致
# 第94次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 1150217664900954371838269646
# 手写与 rsa 库加密结果一致
# 第95次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3545290439150751864985429673
# 手写与 rsa 库加密结果一致
# 第96次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 626695379932778067827658968
# 手写与 rsa 库加密结果一致
# 第97次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 152090594946239761820201569
# 手写与 rsa 库加密结果一致
# 第98次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 538914846429306517731439622
# 手写与 rsa 库加密结果一致
# 第99次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 4766430352079567320400232599
# 手写与 rsa 库加密结果一致
# 第100次测试
# 手写函数的加密结果： 4281657302399292598109324838
# rsa 库的加密结果： 3305882629280628816469428671
# 手写与 rsa 库加密结果一致
